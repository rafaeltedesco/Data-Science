# %%
import pandas as pd

# %%
df = pd.read_csv('letsgo_pokemon.csv')

# %% [markdown]
# Number of Pokemon of Each Type

# %%
df.groupby('Type').agg('count')['Name']
# Out:
# Type
# Bug         14
# Dark         7
# Dragon       5
# Electric    14
# Fairy        6
# Fighting     9
# Fire        15
# Flying      23
# Ghost        5
# Grass       16
# Ground      16
# Ice          9
# Normal      27
# Poison      38
# Psychic     19
# Rock        15
# Steel        8
# Water       35
# Name: Name, dtype: int64

# %% [markdown]
# Median Stats for Each Type

# %%
df.groupby('Type').agg('median')[df.columns[3:]].sort_values(by='Total')
# Out:
#           Total    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# Type
# Steel     375.0  48.0    70.0     80.0     52.5     60.0   55.0
# Rock      390.0  60.0    95.0    105.0     55.0     45.0   45.0
# Bug       395.0  60.0    67.5     52.5     45.0     72.5   60.0
# Poison    395.0  60.5    67.5     58.5     65.0     70.0   58.0
# Grass     405.0  62.5    77.5     75.0     85.0     72.5   47.5
# Ground    407.5  52.5    88.5     95.0     45.0     47.5   55.0
# Dark      413.0  75.0    71.0     60.0     50.0     65.0   77.0
# Normal    413.0  65.0    70.0     60.0     50.0     65.0   72.0
# Ghost     425.0  60.0    65.0     60.0    115.0     75.0   95.0
# Fairy     447.5  84.0    56.0     56.5     83.0     77.5   52.5
# Water     450.0  60.0    70.0     80.0     70.0     70.0   70.0
# Fighting  455.0  70.0   105.0     70.0     50.0     85.0   70.0
# Ice       475.0  73.0    75.0     80.0     81.0     95.0   70.0
# Electric  475.0  57.5    80.0     65.0     85.0     67.5  100.0
# ...
